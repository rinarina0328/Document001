# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
a = np.random.randint(low=0, high=100, size=(3, 4))
a
# Out:
# array([[84, 99, 79, 78],
#        [95, 14,  2, 61],
#        [65, 18, 28, 17]])

# %%
b = pd.DataFrame(a)
b
# Out:
#     0   1   2   3
# 0  84  99  79  78
# 1  95  14   2  61
# 2  65  18  28  17

# %%
type(b)
# Out:
# pandas.core.frame.DataFrame

# %%
b.columns
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
b.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
b.columns = ['c', 'python', 'java', 'swift']
b.index = ['alice', 'bob', 'cathy']
b
# Out:
#         c  python  java  swift
# alice  84      99    79     78
# bob    95      14     2     61
# cathy  65      18    28     17

# %%
b.describe()
# Out:
#                c     python       java      swift
# count   3.000000   3.000000   3.000000   3.000000
# mean   81.333333  43.666667  36.333333  52.000000
# std    15.176737  47.961790  39.170567  31.480152
# min    65.000000  14.000000   2.000000  17.000000
# 25%    74.500000  16.000000  15.000000  39.000000
# 50%    84.000000  18.000000  28.000000  61.000000
# 75%    89.500000  58.500000  53.500000  69.500000
# max    95.000000  99.000000  79.000000  78.000000

# %%
sns.pairplot(b)

# %%
sns.scatterplot(x='c', y='python', size='swift', data=b)

# %%
iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
iris.species.unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
iris['species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
sns.pairplot(iris, hue='species')

# %%
sns.scatterplot(x='sepal_length', y='petal_length', hue='species', data=iris)
